# %% [markdown]
# <a href="https://colab.research.google.com/github/zaafirrahman/python-algorithmics/blob/main/11Module.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from random import *
print(randint(100,500))
# Out:
# 356

# %%
import random
cek = random.randint(1,10)
print(cek)
# Out:
# 10

# %%
from random import *

nomor_menang = 1212
angka_sekarang = randint(1200, 1220)
print('Nomor tiket lotre kamu adalah:', angka_sekarang)

if angka_sekarang == nomor_menang:
    print('Anda menang, selamat!')
else:
    print('Semoga lain kali lebih beruntung!')
# Out:
# Nomor tiket lotre kamu adalah: 1212
# Anda menang, selamat!

# %%
jackpot = 12345
guess = (input("Mulai lotre (enter - start, off - stop)"))
while guess != 'off':
  lot = random.randint(12340,12350)
  print(lot)

  if lot != jackpot:
    print("Nomor Salah")
  else:
    print("Selamat anda menang lotre")
    break

  guess = (input("Mulai lotre (enter - start, off - stop)"))
# Out:
# Mulai lotre (enter - start, off - stop)
# 12345
# Selamat anda menang lotre

# %%
from time import time, sleep

print(time())

waktu1 = time()
# Out:
# 1770198267.1154568

# %%
waktu2 = time()

print(waktu2 - waktu1)
# Out:
# 11.34557056427002

# %%
pi = 3.14181748273

round(pi,2)
# Out:
# 3.14

# %%
mulai = time()
print(mulai)
a = input('isi: ')
selesai = time()
print(selesai)

lama = round(selesai-mulai, 2)
print('Waktu yang diperlukan:', lama)
# Out:
# 1770198754.3509927
# isi: halo semuanya
# 1770198776.362016
# Waktu yang diperlukan: 22.01

# %%
print('Selamat Datang')
sleep(10)
print('Selamat tinggal')
# Out:
# Selamat Datang
# Selamat tinggal

# %%
c = 39.013678
print(round(c))
# Out:
# 39

# %%
start = time()
ketik = input('Tulis suatu kalimat atau paragraf: ')
stop = time()

duration = round(stop - start, 2)
print(f'Lama mengetik: {duration} detik')
size = len(ketik)
print(f'Jumlah karakter: {size} karakter')

cpm = round(size/(duration/60))
print(f'Kecepatan mengetik: {cpm} karakter per menit')
# Out:
# Tulis suatu kalimat atau paragraf: halo namaku agi dan aku sedang belajar python dengan kak zaafir
# Lama mengetik: 12.32 detik
# Jumlah karakter: 63 karakter
# Kecepatan mengetik: 307 karakter per menit
