# %% [markdown]
# <a href="https://colab.research.google.com/github/zaafirrahman/python-algorithmics/blob/main/14Dictionary%26Set.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
nama = ['sabiq','kenzie','devika']
print(nama[1])
# Out:
# kenzie

# %%
barang = {'HP':10,
          'Laptop':5,
          'Tablet':7,
          'Headset':16
          }

# print(barang)

# cek_keys = barang.keys()
# cek_values = barang.values()

# print(cek_keys)
# print(cek_values)

print(barang['Headset'])
# Out:
# 16

# %%
# Berapa pasang barang yang tersedia?
cek_barang = len(barang)
print('Jumlah jenis barang:',cek_barang)

# Berapa stok barang tertentu?
nama = input('Masukkan nama barang: ')
cek_stok = barang[nama]
print('Stok tersedia:',cek_stok)
# Out:
# Jumlah jenis barang: 4
# Masukkan nama barang: Laptop
# Stok tersedia: 5

# %%
# Menambahkan pasangan key value
barang['Speaker'] = 4
print(barang)

# Menghapus pasangan
del barang['Headset']
print(barang)
# Out:
# {'HP': 10, 'Laptop': 5, 'Tablet': 7, 'Headset': 16, 'Speaker': 4}
# {'HP': 10, 'Laptop': 5, 'Tablet': 7, 'Speaker': 4}

# %%
# Mencari keberadaan key value
print('Laptop' in barang)
print('Headset' in barang)
# Out:
# True
# False

# %%
nama = input('Masukkan nama barang: ')
if nama in barang:
    print('Ada')
else:
    print('Tidak ada')
# Out:
# Masukkan nama barang: Mouse
# Tidak ada

# %%
# Contoh program

print('In stock:', barang.keys())
wish = input('Masukkan barang yang diinginkan: ')
if wish in barang:
  print('Jumlah stok tersedia:', barang[wish])
  take = input('Apakah Anda ingin membeli? (ya/tidak) ')
  if take == 'ya':
      print('Pembelian dikonfirmasi')
      barang[wish] -= 1
      print('Jumlah stok tersisa:', barang[wish])
else:
  print('Barang tidak ditemukan')
# Out:
# In stock: dict_keys(['HP', 'Laptop', 'Tablet', 'Keyboard'])
# Masukkan barang yang diinginkan: Tablet
# Jumlah stok tersedia: 7
# Apakah Anda ingin membeli? (ya/tidak) ya
# Pembelian dikonfirmasi
# Jumlah stok tersisa: 6

# %%
my_list = [1, 2, 3, 4, 1, 2, 3, 2, 2]
numbers = set(my_list)
numbers.add(5)
numbers.remove(4)
print(numbers)
# Out:
# {1, 2, 3, 5}

# %%
my_songs = {
    'Sunset di Tanah Anarki':'Superman is Dead',
    'Pikiran dan Perjalanan':'Barasuara',
    'Queen of The South':'The Panturas',
    'Dapur Keluarga':'.Feast',
    'Fatalis':'Barasuara',
    'Politrik':'.Feast'
}

# %%
artist1 = my_songs.values()
print(artist1)
# print('Daftar penulis (Dictionary):')
# for i in artist1:
#     print(i)
# Out:
# dict_values(['Superman is Dead', 'Barasuara', 'The Panturas', '.Feast', 'Barasuara', '.Feast'])

# %%
artist2 = set(my_songs.values())
print(artist2)
# print('Daftar penulis (Set):')
# for i in artist2:
#     print(i)
# Out:
# {'Barasuara', 'Superman is Dead', 'The Panturas', '.Feast'}

# %%
your_songs = {
    'Is It The Answer':'Reality Club',
    'Nina':'.Feast',
    'Kita ke Sana':'Hindia',
    'Terbuang Dalam Waktu':'Barasuara',
    'Secukupnya':'Hindia',
    'Gala Bunga Matahari':'Sal Priadi'
}

# %%
my_set = set(my_songs.values())
your_set = set(your_songs.values())

print(my_set)
print(your_set)
# Out:
# {'Barasuara', 'Superman is Dead', 'The Panturas', '.Feast'}
# {'Barasuara', 'Sal Priadi', '.Feast', 'Reality Club', 'Hindia'}

# %%
print('Daftar seluruh artist:', my_set.union(your_set))
print('Artist favorit keduanya:', my_set.intersection(your_set))
print('Saya tidak menyukai:', your_set.difference(my_set))
print('Kamu tidak menyukai:', my_set.difference(your_set))
# Out:
# Daftar seluruh artist: {'Superman is Dead', 'The Panturas', 'Barasuara', 'Sal Priadi', '.Feast', 'Reality Club', 'Hindia'}
# Artist favorit keduanya: {'Barasuara', '.Feast'}
# Saya tidak menyukai: {'Sal Priadi', 'Reality Club', 'Hindia'}
# Kamu tidak menyukai: {'Superman is Dead', 'The Panturas'}
