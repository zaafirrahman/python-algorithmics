# %% [markdown]
# <a href="https://colab.research.google.com/github/zaafirrahman/python-algorithmics/blob/main/15NestedDict.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
list_asal = ['cek', 1, 0.5, True, ['Nomor', 1.8], (False, 5), {1, 2, 3}, {'Huruf':'Z', 'Nomor':26}]
print(list_asal[-1])
# Out:
# {'Huruf': 'Z', 'Nomor': 26}

# %%
list_asal = ['cek', 1, 0.5, True, ['Nomor', 1.8], (False, 5), {1, 2, 3}, {'Huruf':'Z', 'Nomor':26}]
set1 = set(list_asal)
print(set1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_499/2500603741.py in <cell line: 0>()
#       1 list_asal = ['cek', 1, 0.5, True, ['Nomor', 1.8], (False, 5), {1, 2, 3}, {'Huruf':'Z', 'Nomor':26}]
# ----> 2 set1 = set(list_asal)
#       3 print(set1)
#
# TypeError: unhashable type: 'list'

# %%
cth_dict = {
    'Huruf':'Z',
    123:26,
    True:False,
    'List':[1,2,3],
    'Tuple':(2,3,4),
    'Dict':{'Buku':'Harry Potter'},
    'Set':{1,2,3}
}

cth_dict2 = {
    (1,3,5):'Ganjil',
     (2,4,6):'Genap'
}
print(cth_dict)
# Out:
# {'Huruf': 'Z', 123: 26, True: False, 'List': [1, 2, 3], 'Tuple': (2, 3, 4), 'Dict': {'Buku': 'Harry Potter'}, 'Set': {1, 2, 3}}

# %%
staff = ['Johnson', 'Thomas']
staff2 = ['Johnson', ['ProTeam', ['PlayForever','PlayNotForever']]]

print(staff2[1][1])
# Out:
# ['PlayForever', 'PlayNotForever']

# %%
a = 'agi'
b = [2,3]

print(len(b))
# Out:
# 2

# %%
materi = [
    'Print',
    'Tipe Data',
    'Kondisi',
    ['Loop While','Loop For'],
    'Fungsi',
    ['List','Tuple','Dictionary','Set']
]

print(materi[5][2][9])
# Out:
# y

# %%
list1 = [1,2,3]

# %%
# staff = [
#   {'Johnson': 'programmer'},
#   {'Thomas': 'tester'}
# ]

staff = [
  {'Johnson': ['ProTeam', 'PlayForever'], 'Algo':'Python'},
  {'Thomas': 'ProTeam'}
]

print(staff[0]['Johnson'][1])
# Out:
# PlayForever

# %%
staff = {
   'Johnson': {
       'posisi': 'programmer',
       'pengalaman': ['ProTeam', 'PlayForever']
       },
   'Thomas': {
       'posisi': 'tester',
       'pengalaman': ['ProTeam']
       }
}

# %%
# print(staff)
# print(staff['Johnson'])
# print(staff['Johnson']['posisi'])
# print(staff['Johnson']['pengalaman'])
print(staff['Johnson']['pengalaman'][1][0])
# Out:
# P

# %%
surname = input('Masukkan nama belakang: ')
for info in staff[surname]:
   print(info, '-', staff[surname][info])
# Out:
# Masukkan nama belakang: Thomas
# posisi - tester
# pengalaman - ['ProTeam']
