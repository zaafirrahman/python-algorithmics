# %% [markdown]
# <a href="https://colab.research.google.com/github/zaafirrahman/python-algorithmics/blob/main/15NestedDict.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
list_asal = ['cek', 1, 0.5, True, ['Nomor', 1.8], (False, 5), {1, 2, 3}, {'Huruf':'Z', 'Nomor':26}]
print(list_asal)
# Out:
# ['cek', 1, 0.5, True, ['Nomor', 1.8], (False, 5), {1, 2, 3}, {'Huruf': 'Z', 'Nomor': 26}]

# %%
cth_dict = {
    'Huruf':'Z',
    123:26,
    True:False,
    'List':[1,2,3]
}

cth_dict2 = {
    (1,3,5):'Ganjil',
     (2,4,6):'Genap'
}
print(cth_dict2)
# Out:
# {(1, 3, 5): 'Ganjil', (2, 4, 6): 'Genap'}

# %%
staff = ['Johnson', 'Thomas']
staff = ['Johnson', ['ProTeam', 'PlayForever']]

print(staff[1][1][1])
# Out:
# l

# %%
a = 'agi'
b = [2,3]

print(len(b))
# Out:
# 2

# %%
materi = [
    'Print',
    'Tipe Data',
    'Kondisi',
    ['Loop While','Loop For'],
    'Fungsi',
    ['List','Tuple','Dictionary','Set']
]

print(materi[5][2][9])
# Out:
# y

# %%
staff = [
  {'Johnson': 'programmer'},
  {'Thomas': 'tester'}
]

staff = [
  {'Johnson': ['ProTeam', 'PlayForever'], 'Algo':['Python']},
  {'Thomas': ['ProTeam']}
]

print(staff[0]['Johnson'])
# Out:
# ['ProTeam', 'PlayForever']

# %%
staff = {
   'Johnson': {
       'posisi': 'programmer',
       'pengalaman': ['ProTeam', 'PlayForever']
       },
   'Thomas': {
       'posisi': 'tester',
       'pengalaman': ['ProTeam']
       }
}

# %%
# print(staff)
# print(staff['Johnson'])
# print(staff['Johnson']['posisi'])
# print(staff['Johnson']['pengalaman'])
print(staff['Johnson']['pengalaman'][1][3])
# Out:
# y

# %%
surname = input('Masukkan nama belakang: ')
for info in staff[surname]:
   print(info, '-', staff[surname][info])
# Out:
# Masukkan nama belakang: Thomas
# posisi - tester
# pengalaman - ['ProTeam']
