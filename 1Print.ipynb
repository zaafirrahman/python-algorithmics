# %% [markdown]
# <a href="https://colab.research.google.com/github/zaafirrahman/python-algorithmics/blob/main/1Print.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print('Halo nama saya Evan')
print('Umur saya', 3, "tahun")
print(1)
# Out:
# Halo nama saya Evan
# Umur saya 3 tahun
# 1

# %%
print(10.5/4)
print(6*7)
print(15+17)
print(10-5)
print('Total adalah', 7*5+10/2)
# Out:
# 2.625
# 42
# 32
# 5
# Total adalah 40.0
