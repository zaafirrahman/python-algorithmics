# %% [markdown]
# <a href="https://colab.research.google.com/github/zaafirrahman/python-algorithmics/blob/main/2Variable.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
x = 3
y = 5
z = 2

print(x + y - z + x)
# Out:
# 6

# %%
nama = 'Azka'
usia = 13
les = 'Math'

print('Halo nama saya', nama, 'usia saya', usia, 'tahun, dan saya ikut kursus', les)
# Out:
# Halo nama saya Azka usia saya 13 tahun, dan saya ikut les Math

# %%
a = 2.5 #float (float)
b = 1000 #integer (int)
c = '6' #string (str)

print(int('5') + 7)
# Out:
# 12

# %%
kelas = 7
nama_Lengkap = 'Azka Mawlana'
ANGKA = 6
angk4 = 8
# Out:
#   File "/tmp/ipython-input-117629264.py", line 2
#     nama Lengkap = 'Azka Mawlana'
#          ^
# SyntaxError: invalid syntax

# %%
nama_klien = 'Naura'
harga = 10000
jumlah_tiket = 5

print('Nama klien adalah:', nama_klien)
print('Total harga tiket:', harga * jumlah_tiket)
# Out:
# Nama klien adalah: Naura
# Total harga tiket: 50000

# %%
namaLengkap = 'Karina Lianda'
print(namaLengkap)
# Out:
# Karina Lianda

# %%
x = 'Angeline'
x = 'Rayan'

print(x)
# Out:
# Rayan

# %%
Biodata = 'Rayan'
CONSTANT = 5

# %%
bilanganPertama = 10
print(bilanganPertama)
# Out:
# 10

# %%
nama_orang = 'Zaky'

print('Nama saya', nama_orang)
# Out:
# Nama saya Zaky

# %%
nama = 'Karina'
usia = 14

print(f'Nama dia adalah {nama} usianya adalah {usia} tahun')
# Out:
# Nama dia adalah Karina usianya adalah 14 tahun

# %%
harga = 19000
diskon = 1500

total = harga-diskon
print(total)
# Out:
# Masukkan harga: 30000
# 25500.0

# %%
kursus = 'Python'
peserta = 5

print(f'Terdapat {peserta} murid di kelas {kursus}')
# Out:
# Terdapat 5 murid di kelas Python

# %%
print(5+3)
# Out:
# 8

# %%
hari = 22
gaji_harian = 1000
gaji_harian = 2000
total = gaji_harian * hari

print(total)
# Out:
# 44000

# %%
makanan = input('Masukkan makanan kesukaan Anda: ')

print('Makanan kesukaanmu adalah', makanan)
# Out:
# Masukkan makanan kesukaan Anda: cilok
# Makanan kesukaanmu adalah cilok

# %%
angka = int(input('Masukkan angka: '))

print(angka + 7)
# Out:
# Masukkan angka: 5
# 12

# %%
angka1 = int(input('Masukkan angka pertama: '))
angka2 = int(input('Masukkan angka kedua: '))

print('Hasilnya adalah', angka1 - angka2)
# Out:
# Masukkan angka pertama: 12
# Masukkan angka kedua: 25
# Hasilnya adalah -13

# %%
makanan = input('Sebutkan makanan kesukaanmu: ')

print('Makanan kesukaanmu adalah', makanan)

# %%
x = input('Masukkan angka: ')
x = float(x)
hasil = x + 2

print('Hasilnya adalah', hasil)
# Out:
# Masukkan angka: 10.7
# Hasilnya adalah 12.7

# %%
angka1 = int(input('Masukkan angka pertama '))
angka2 = int(input('Masukkan angka kedua '))

total = angka1 - angka2

print('Hasil penjumlahan:', total)
# Out:
# Masukkan angka pertama 12
# Masukkan angka kedua 25
# Hasil penjumlahan: -13

# %%
course = input('Masukkan nama kursus : ')
student = input('Masukkan jumlah peserta: ')

print('Terdapat', student, 'murid di kelas', course)
# Out:
# Masukkan nama kursus : algonova
# Masukkan jumlah peserta: 5400
# Terdapat 5400 murid di kelas algonova

# %%
tambahan_jasa = int(input('Harga dari jasa tambahan:'))
total = 2500 + tambahan_jasa
print('Harga total:', total)
# Out:
# Harga dari jasa tambahan:5000
# Harga total: 7500

# %%
angka1 = int(input('Masukkan angka pertama:'))
angka2 = int(input('Masukkan angka kedua:'))

total = angka1 + angka2

print('Hasil penjumlahan:', total)

# %%
b = input('masukan angka ')
b = int(b)
# Out:
# masukan angka 5

# %%
int(input('Masukkan angka pertama:'))
