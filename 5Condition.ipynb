# %% [markdown]
# <a href="https://colab.research.google.com/github/zaafirrahman/python-algorithmics/blob/main/5Condition.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **TIPE DATA LOGIKA (BOOLEAN)**

# %%
# float
# integer
# string
# boolean

# %%
a = int(input('a = '))
b = int(input('b = '))
print('--------------')

print('a > b ', a > b)
print('a < b ', a < b)
print('a == b ', a == b)
print('a != b ', a != b)
# Out:
# a = 3
# b = 5
# --------------
# a > b  False
# a < b  True
# a == b  False
# a != b  True

# %%
pesanan = int(input('Jumlah pesanan: '))
stok = int(input('Jumlah stok: '))

print('-'*10)
print('Pesanan tersedia:', pesanan <= stok)
# Out:
# Jumlah pesanan: 5
# Jumlah stok: 5
# ----------
# Pesanan tersedia: True

# %%
c = int(input('c = '))
d = int(input('d = '))
print('--------------')

print('c > d or d > c ', c>d or d>c)
print('c > d and d > c ', c>d and d>c)
print('c > d and d < c ', c>d and d<c)
# Out:
# c = 3
# d = 5
# --------------
# c > d or d > c  True
# c > d and d > c  False
# c > d and d < c  False

# %%
stok = int(input('Jumlah stok yang masuk: '))
print('----------------------------')

print('Stok diizinkan masuk:', stok >= 50 and stok <= 300)
# Out:
# Jumlah stok yang masuk: 400
# ----------------------------
# Stok diizinkan masuk: False

# %% [markdown]
# # **OPERATOR BERSYARAT**

# %%
angka = 1

if angka > 2:
  print('kondisi benar')
else:
  print('kondisi salah')
# Out:
# kondisi salah

# %%
rasa_favorit = input('Masukkan rasa favorit Anda (misalnya, manis, pedas, gurih): ')
rasa_favorit = rasa_favorit.lower()

if rasa_favorit == 'manis':
    print('Rekomendasi makanan untuk Anda: Kue, Cokelat, atau Es Krim.')
elif rasa_favorit == 'asam':
    print('Rekomendasi makanan untuk Anda: Jeruk, Apel ijo.')
elif rasa_favorit == 'pedas':
    print('Rekomendasi makanan untuk anda: Baso mercon')
# Out:
# Masukkan rasa favorit Anda (misalnya, manis, pedas, gurih): gurih

# %%
angka = int(input('Masukkan sebuah angka: '))

if angka > 0:
    print('Angka yang Anda masukkan adalah positif.')
elif angka == 0:
    print('Angka yang Anda masukkan adalah nol.')
else:
    print('Angka yang Anda masukkan adalah negatif.')
# Out:
# Masukkan sebuah angka: -9
# Angka yang Anda masukkan adalah negatif.

# %%
a = int(input('masukkan angka pertama: '))
b = 67

if a > b:
    print('a lebih besar dari b')
else:
    print('a lebih kecil dari b')
# Out:
# masukkan angka pertama: 67
# a lebih kecil dari b
