# %% [markdown]
# <a href="https://colab.research.google.com/github/zaafirrahman/python-algorithmics/blob/main/8LoopFor.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
word = 'algorithmicss'
for i in word:
   print(i)

print('Program Selesaii')
# Out:
# a
# l
# g
# o
# r
# i
# t
# h
# m
# i
# c
# s
# Program Selesai

# %%
nama = ['angeline', 'karina', 'zaky', 'rayan']
for i in nama:
   print(i)
# Out:
# angeline
# karina
# zaky
# rayan

# %%
password = input('Masukkan password: ')
alphabet = 'abcdefghijklmnopqrstuvwxyz'
for i in password:
   print(alphabet.find(i)+1)
# Out:
# Masukkan password: rayan
# 18
# 1
# 25
# 1
# 14

# %%
login = input('Masukkan info masuk: ')
wrong = '=?*^$№@_'
for i in login:
   if i in wrong:
       print('Simbol terlarang: ', i)
# Out:
# Masukkan info masuk: za@fir*
# Simbol terlarang:  @
# Simbol terlarang:  *

# %%
for i in range(5): # range (stop)
  print(i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
for i in range(9,15): # range (start, stop)
  print(i)
# Out:
# 9
# 10
# 11
# 12
# 13
# 14

# %%
for i in range(2,10,2): # range(start, stop, jump)
  print(i)
# Out:
# 2
# 4
# 6
# 8

# %%
jumlah = int(input('Jumlah anggota: '))

for i in range(jumlah):
   name = input('Masukkan nama: ')
   print('Selamat datang,', name)

print('Obrolan grup telah dibuat!')
# Out:
# Jumlah anggota: 8
# Masukkan nama: a
# Selamat datang, a
# Masukkan nama: b
# Selamat datang, b
# Masukkan nama: c
# Selamat datang, c
# Masukkan nama: d
# Selamat datang, d
# Masukkan nama: e
# Selamat datang, e
# Masukkan nama: f
# Selamat datang, f
# Masukkan nama: g
# Selamat datang, g
# Masukkan nama: h
# Selamat datang, h
# Obrolan grup telah dibuat!

# %%
for i in range(1, 6):
    print(i, "^2 =", i**2)
# Out:
# 1 ^2 = 1
# 2 ^2 = 4
# 3 ^2 = 9
# 4 ^2 = 16
# 5 ^2 = 25
