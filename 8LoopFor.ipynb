# %% [markdown]
# <a href="https://colab.research.google.com/github/zaafirrahman/python-algorithmics/blob/main/8LoopFor.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
word = ''
for i in word:
   print(i)

print('Program Selesaii')

# %%
krisna = ['doors', 'rush', 'ambush', 'adminconsolehelloneighbor']
for i in krisna:
   print(i)
# Out:
# doors
# rush
# ambush
# adminconsolehelloneighbor

# %%
password = input('Masukkan password: ')
alphabet = 'abcdefghijklmnopqrstuvwxyz'
for i in password:
   print(alphabet.find(i)+1)
# Out:
# Masukkan password: rush
# 18
# 21
# 19
# 8

# %%
login = input('Masukkan info masuk: ')
wrong = '=?*^$№@_'
for i in login:
   if i in wrong:
       print('Simbol terlarang: ', i)
# Out:
# Masukkan info masuk: za@fir*
# Simbol terlarang:  @
# Simbol terlarang:  *

# %%
for i in range(100): # range (stop)
  print('rush and ambush')

# %%
for i in range(6,12): # range (start, stop)
  print(i)
# Out:
# 6
# 7
# 8
# 9
# 10
# 11

# %%
for i in range(10,2,-1): # range(start, stop, jump)
  print(i)
# Out:
# 10
# 9
# 8
# 7
# 6
# 5
# 4
# 3

# %%
jumlah = int(input('Jumlah anggota: '))

for i in range(jumlah):
   name = input('Masukkan nama: ')
   print('Selamat datang,', name)

print('Obrolan grup telah dibuat!')
# Out:
# Jumlah anggota: 3
# Masukkan nama: krisna
# Selamat datang, krisna
# Masukkan nama: rush
# Selamat datang, rush
# Masukkan nama: ambush
# Selamat datang, ambush
# Obrolan grup telah dibuat!

# %%
for i in range(1, 6):
    print(i, "^2 =", i**2)
# Out:
# 1 ^2 = 1
# 2 ^2 = 4
# 3 ^2 = 9
# 4 ^2 = 16
# 5 ^2 = 25
