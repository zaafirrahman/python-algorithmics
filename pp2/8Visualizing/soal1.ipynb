# %%
import matplotlib.pyplot as plt
import pandas as pd
df = pd.read_csv('GoogleApps.csv')

# %%
s = pd.Series(data = [10, 5, 15, 20, 10],
 index = [1, 2, 3, 4, 5])
s.plot()
plt.show()

# %%
df['Size'].plot(kind = 'hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
df['Size'].plot(kind = 'hist', bins = 5)
# Out:
# <Axes: ylabel='Frequency'>

# %%
df[df['Type'] == 'Paid']['Price'].plot(kind = 'hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
df['Category'].value_counts().plot(kind = 'pie')
# Out:
# <Axes: ylabel='count'>

# %%
df[df['Type'] == 'Paid']['Price'].plot(kind = 'box')
# Out:
# <Axes: >

# %%
df['Size'].plot(kind = 'box')
# Out:
# <Axes: >

# %%
df.plot(x = 'Rating', y = 'Size', kind = 'scatter')
# Out:
# <Axes: xlabel='Rating', ylabel='Size'>

# %%
# Ex: Shipping cost data w/ distance & duration as x
Y = [230,70,150,170,230,220,100,140,200,190] #cost($)
x1 = [1050,236,417,620,837,709,412,646,738,613] #distance(mile)
x2 = [7,3,2,4,6,5,3,3,4,3] #duration(hour)
df2 = pd.DataFrame({'Y':Y,'x1':x1,'x2':x2})

# %%
df2.plot(x = 'x2', y = 'Y', kind = 'scatter')
# Out:
# <Axes: xlabel='x2', ylabel='Y'>

# %%
df['Content Rating'].value_counts().plot(kind = 'bar')
# Out:
# <Axes: xlabel='Content Rating'>

# %%
df['Category'].value_counts().plot(kind = 'barh', grid = True)
# Out:
# <Axes: ylabel='Category'>

# %%
df['Category'].value_counts().plot(kind = 'barh', figsize = (8, 5), grid = True)
# Out:
# <Axes: ylabel='Category'>

# %%
d1 = df[df['Type'] == 'Free'].groupby('Content Rating')['Installs'].mean()
d2 = df[df['Type'] == 'Paid'].groupby('Content Rating')['Installs'].mean()
d1.plot(kind = 'barh')
d2.plot(kind = 'barh')
# Out:
# <Axes: ylabel='Content Rating'>

# %%
d = df.pivot_table(index = 'Content Rating', 
 	columns = 'Type', 
 	values = 'Installs', 
 	aggfunc = 'mean')

# %%
d.plot(kind = 'barh', subplots = True)
# Out:
# array([<Axes: title={'center': 'Free'}, ylabel='Content Rating'>,
#        <Axes: title={'center': 'Paid'}, ylabel='Content Rating'>],
#       dtype=object)

# %%
d.plot(kind = 'barh', grid = True)
# Out:
# <Axes: ylabel='Content Rating'>
